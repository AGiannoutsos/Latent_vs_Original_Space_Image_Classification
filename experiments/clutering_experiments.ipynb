# %% [markdown]
# # New space, Origninal space, Classes as clusters

# %% [markdown]
# # Time

# %%
spaces = ["New space", "Original Space", "Classes as clusters"]
time = [3207.23, 53021.3, 1000]

fig, ax = plt.subplots(1,1,  figsize=(10, 5))
ax.bar(spaces, time)
ax.set_title("Clustering Time")
ax.set_xlabel("Time")
ax.set_ylabel("Spaces")
plt.savefig('clustering_time.png')
pass

# %% [markdown]
# # Objective error

# %%
spaces = ["New space", "Original Space", "Classes as clusters"]
time = [1.64845, 1.63368, 1.65861]

fig, ax = plt.subplots(1,1,  figsize=(10, 5))
ax.bar(spaces, time)
ax.set_title("Objective error")
ax.set_xlabel("Error")
ax.set_ylabel("Spaces")
plt.savefig('Objective_error.png')
pass

# %% [markdown]
# # Silhouettes

# %%
spaces = ["New space", "Original Space", "Classes as clusters"]
time = [0.067152,  0.063695, 0.063695]

fig, ax = plt.subplots(1,1,  figsize=(10, 5))
ax.bar(spaces, time)
ax.set_title("Silhouettes")
ax.set_xlabel("Silhouette")
ax.set_ylabel("Spaces")
plt.savefig('silhouettes.png')
pass

# %% [markdown]
# # Results

# %% [markdown]
# From the results we can see that clustering in the real space of dimensions takes much more time than that in smaller dimensions with the use of a neural network.
#
# In addition the cost of the objective function as well as the price of the silhouette are almost similar compared to the real space.
# Therefore the reduction of dimensions in smaller vector spaces seems to be quite useful for clustering in relation to the computation in real space
